# %% [markdown]
# #DATASCI 261 Final Project Phase 1 Submission Notebook

# %% [markdown]
# #FlightDelay Lab: A Scalable Machine Learning Pipeline for Predicting Airline Flight Delays Using Flight and Weather Data

# %% [markdown]
# # Table of Contents
#
# ## 1. Project Managemnet
# - [Phase Leader Plan](##phase-leader-plan)
# - [Credit Assignment Plan](##credit-assignment-plan)
# - [Gantt](##gantt)
#
#
# ## 2. Project Overview
# - [Abstract](##abstract)
# - [Problem Statement](##problem-statement)
# - [Stakeholders](##stakeholders)
#
# ## 3. Data
# - [Data Description](#data-description)
#   - [Stations + Airport Codes Dataset](##airport-codes-dataset)
#   - [Weather Dataset](##weather-dataset)
#   - [Flights Dataset](#flights-dataset)
#   - [OPTW Dataset](#OPTW-dataset)
#
#
# ## 4. Exploratory Data Analysis
# - [EDA Overview](#exploratory-data-analysis)
# - [Delay Distribution Analysis](#delay-distribution-analysis)
# - [Weather Station Distance Analysis](#weather-station-distance-analysis)
# - [Airport Geographic Distribution](#airport-geographic-distribution)
#
# ## 5. Learning Methodology and Evaluation
# - [Machine Learning Algorithms](#machine-learning-algorithms)
#   - [Problem Formulation](#problem-formulation)
#   - [Baseline Models](#baseline-models)
#   - [Advanced Models](#advanced-models)
#   - [Modeling Strategy](#modeling-strategy)
#   - [Successful Evaluation Metrics](#successful-evaluation-metrics)
#
# ## 6. Model Pipeline
# - [Machine Learning Pipeline](#machine-learning-pipeline)

# %% [markdown]
# # Project Management

# %% [markdown]
# ## Phase Leader Plan
#
# | **Project Phase** | **Leader(s)**             | **Email**                                       |
# |-------------------|---------------------------|--------------------------------------------------|
# | Phase 1           | Frank Lin                 | frank_tingchun_lin@berkeley.edu                  |
# | Phase 2           | Daniel Yi and William Shu | daniel_yi@berkeley.edu, william.shu@berkeley.edu |
# | Phase 3           | Allen Li and Jason Chang  | allen_li@berkeley.edu, chan572@berkeley.edu      |

# %% [markdown]
# ## Credit Assignment Plan
#
# ### Phase 1 (Due 3/15)
#
# | **Task**                                 | **Task Type** | **Effort Hours** | **Assigned To**          |
# |------------------------------------------|---------------|------------------|--------------------------|
# | Credit Assignment Plan                   | Report        |                2 | Daniel Yi                |
# | Project Abstract                         | Report        |                2 | Frank Lin                |
# | Data Description                         | Report        |                2 | Frank Lin,  William Shu  |
# | EDA for Weather Dataset                  | EDA           |                4 | Allen Y Li               |
# | EDA for Airports + Airport Codes Dataset | EDA           |                2 | Frank Lin  |
# | EDA for Flights Dataset                  | EDA           |                2 | Daniel Yi                |
# | EDA for OTPW Dataset                     | EDA           |                4 | William Shu, Jason Chang |
# | Summary EDA for All Datasets             | Report        |                2 | Frank Lin, Jason Chang   |
# | Machine Learning Algorithm Discussion    | Modeling      |                4 | Allen Y Li, Frank Lin    |
# | Metrics Discussion                       | Report        |                1 | Frank Lin, William Shu   |
# | Gantt Chart                              | Report        |                1 | Daniel Yi                |
# | Pipeline Description                     | Modeling      |                1 | Jason Chang, William Shu |
# | Team Member Emails                       | Report        |              0.5 | All                      |
# | Feature Engineering Plan                 | Report        |                1 | Daniel Yi, William Shu   |
# | Open Problems + Next Steps               | Report        |                  | Frank Lin, William Shu   |
# | Report Finalization                      | Report        |                  | Frank Lin                |
#
# ### Phase 2 (Due 4/5)
#
# | **Task**                                                  | **Task Type**     | **Effort Hours** | **Assigned To** |
# |-----------------------------------------------------------|-------------------|------------------|-----------------|
# | EDA for Weather Dataset (Cont.)                           | EDA               |                  | TBD             |
# | EDA for Airports + Airport Codes Dataset (Cont.)          | EDA               |                  | TBD             |
# | EDA for Flights Dataset (Cont.)                           | EDA               |                  | TBD             |
# | EDA for OTPW Dataset (Cont.)                              | EDA               |                  | TBD             |
# | Feature Engineering + Feature Transformation + Discussion | Report + Modeling |                  | TBD             |
# | Model Three-month OTPW Dataset and perform experiments    | Modeling          |                  | TBD             |
# | Model One-year OTPW Dataset and perform experiments       | Modeling          |                  | TBD             |
# | Model Experiment Discussion + Cross Validation            | Report            |                  | TBD             |
# | Create new features (at least one time-based feature)     | Report + Modeling |                  | TBD             |
# | Discuss Modeling piplines and features                    | Report            |                  | TBD             |
# | Updated Credit Assignment Plan                            | Report            |                  | TBD             |
# | Updated Abstract                                          | Report            |                  | TBD             |
# | Updated Conclusion + Next Steps                           | Report            |                  | TBD             |
# | In-class Presentation                                     | Presentation      |                  | TBD             |
# | Conclusion + Next Steps                                   | Report            |                  | TBD             |
# | Open Issue or Problems                                    | Report            |                  | TBD             |
# | Report Finalization                                       | Report            |                  | TBD             |
#
# ### Phase 3 (Due 4/18)
#
# | **Task**                                                                                | **Task Type**     | **Effort Hours** | **Assigned To** |
# |-----------------------------------------------------------------------------------------|-------------------|------------------|-----------------|
# | Consider more sophisticated models (GBDT, MLP neural networks, etc.)                    | Report + Modeling |                  | TBD             |
# | Fine-tune your pipeline using a grid search, or any search techniques                   | Report + Modeling |                  | TBD             |
# | Do experiments on ALL the data for new features and experimental settings               | Report + Modeling |                  | TBD             |
# | Feature engineering and refinement (at least one Time-based feature and Graph feature)  | Report + Modeling |                  | TBD             |
# | Exciting novel directions that you pursued                                              | Report + Modeling |                  | TBD             |
# | Final Abstract                                                                          | Report            |                  | TBD             |
# | Data and Feature Engineering (EDA)                                                      | Report            |                  | TBD             |
# | Neural Network (MLP)                                                                    | Report            |                  | TBD             |
# | Leakage                                                                                 | Report            |                  | TBD             |
# | Modeling Pipeline                                                                       | Report            |                  | TBD             |
# | Results and discussion of results + Gap Analysis of Best Model                          | Report            |                  | TBD             |
# | Concusion                                                                               | Report            |                  | TBD             |
# | Clean Code + Report Finalization                                                        | Report            |                  | TBD             |
# | In-class Presentation                                                                   | Presentation      |                  | TBD             |

# %% [markdown]
# ### Gantt
#
# <img src="https://raw.githubusercontent.com/william-shu-ucb/261-Final-Team-3_2/refs/heads/main/images/gantt.png" width="900"><br>

# %% [markdown]
# [Back to Table of Contents](#table-of-contents)

# %% [markdown]
# # Project Overview

# %% [markdown]
# ## Abstract
#
# Flight delays represent a major operational challenge for airlines and airports, leading to increased operational costs, inefficient resource allocation, and reduced passenger satisfaction. In this project, we aim to develop a scalable machine learning pipeline to predict airline flight delays using the On-Time Performance and Weather (OTPW) dataset. This dataset integrates airline operational data, airport metadata, and meteorological observations, enabling analysis of how environmental conditions and operational factors influence flight delays.
#
# Exploratory data analysis reveals several important characteristics of the dataset. The distribution of departure delays is highly **right-skewed**, with most flights experiencing little or no delay while a smaller subset experiences significant disruptions. Additionally, analysis of the weather station–airport mapping shows that most airports rely on nearby weather stations for observations, although some airports depend on stations located farther away. These findings suggest that **weather conditions, temporal patterns, and operational factors** are likely important drivers of delay behavior.
#
# To address this problem, we will build a distributed machine learning pipeline using Apache Spark to efficiently process large-scale aviation datasets. The primary modeling task will be formulated as a regression problem, predicting the continuous delay variable (`DEP_DELAY`) in minutes. Predicted delay values will then be converted into **operational delay categories (0–15, 15–45, and 45+ minutes)** to support decision-making by airlines and airport operators. We will evaluate several machine learning models, including **linear regression, logistic regression, tree-based ensemble models (Random Forest, Gradient Boosted Trees, and LightGBM), and neural networks**, and compare their performance using appropriate regression and classification metrics. The goal is to identify key drivers of flight delays and develop predictive models that can support **data-driven operational planning in the aviation industry**.

# %% [markdown]
# ## Problem Statement
#
# Flight delays create cascading disruptions across the aviation system, affecting airlines, airports, and passengers. Delays increase operational costs, reduce aircraft and crew utilization efficiency, and negatively impact passenger satisfaction. Being able to accurately predict flight delays before departure would allow airlines and airport operators to proactively manage resources, communicate with passengers, and adjust schedules to mitigate downstream disruptions.
#
# In this project, we aim to develop a machine learning pipeline capable of **predicting the expected departure delay of a flight in minutes**. The prediction must be generated **at least two hours prior to the scheduled departure time**, meaning that the model can only use information available before that point. This constraint ensures that the prediction system reflects a realistic operational setting for airline decision-making.
#
# To address this problem, we use the **On-Time Performance and Weather (OTPW) dataset**, which integrates airline operational data with meteorological observations. The dataset enables analysis of how factors such as **weather conditions, airport characteristics, airline operations, and temporal patterns** influence flight delay behavior.
#
# The primary modeling task is formulated as a **regression problem**, where the model predicts the continuous delay variable `DEP_DELAY` (measured in minutes). For operational interpretation, the predicted delay values will also be mapped into **three delay categories**:
# - **0–15 minutes:** No delay
# - **15–45 minutes:** Moderate delay
# - **45+ minutes:** Major delay
#
# Because aviation datasets are large and complex, we will build a scalable data processing and modeling pipeline using **Apache Spark**, enabling efficient distributed processing of large-scale flight and weather data.

# %% [markdown]
# ## Stakeholders
#
# Several stakeholders could benefit from accurate flight delay prediction models:
#
# #### Airlines
# Airlines can use delay predictions to improve operational planning and reduce disruption costs. Accurate predictions allow airlines to better manage aircraft rotations, crew scheduling, and passenger communication.
#
# #### Airport Authorities
# Airport operators can use delay forecasts to improve gate allocation, runway scheduling, and ground service coordination, helping reduce congestion during peak operational periods.
#
# #### Air Traffic Control and Aviation Regulators
# Organizations responsible for managing airspace and ensuring safety can benefit from predictive insights that help anticipate congestion and coordinate traffic flow more effectively.
#
# #### Passengers
# Passengers benefit from earlier delay notifications, allowing them to adjust travel plans, rebook flights, or make alternative arrangements.
#
# Overall, predictive delay models can contribute to **improved operational efficiency and a better passenger experience across the aviation ecosystem.**

# %% [markdown]
# [Back to Table of Contents](#table-of-contents)

# %% [markdown]
# # Data Description

# %% [markdown]
# ### Stations + Airport Codes Dataset
#
# The **Stations dataset (`df_stations`)** and the **Airport Codes dataset (`df_airport_codes`)** are used together to link flight operations with nearby weather observations. These datasets provide the foundation for integrating meteorological conditions into the flight delay prediction problem.
#
# The **Stations dataset** maps weather stations to nearby airports and records the distance between them. Each row represents a relationship between a weather station and an airport, allowing weather observations from the station to be used as a proxy for airport weather conditions. The dataset contains more than 5 million station–airport relationships, providing broad geographic coverage.
#
# Analysis of the `distance_to_neighbor` variable shows that the average station-to-airport distance is approximately 1,343 units, with considerable variation across airports. Distances range from 0 (stations located directly at airports) to more than 6,400 units, indicating that some airports rely on weather stations that are relatively far away. This variability suggests that weather measurements may differ in representativeness depending on station proximity, making station distance a potentially useful feature or filtering criterion when constructing weather-based features.
#
# The **Airport Codes dataset** provides metadata describing airports around the world. Key attributes include airport identifiers (`ident`), airport type, geographic region, municipality, elevation, and geographic coordinates. While the dataset contains global airport metadata, it is heavily skewed toward small airports and heliports, with only about **600 airports classified as large airports. These large airports represent the most relevant subset for modeling scheduled commercial airline operations.
#
# To enable geographic analysis and visualization, the `coordinates` field was separated into latitude and longitude variables. A geographic scatter plot of airport locations shows a high concentration of airports in North America, particularly within the United States. See Geographic Distribution of Airports below.
#
# <table>
#   <tr>
#     <td><img src="https://raw.githubusercontent.com/william-shu-ucb/261-Final-Team-3_2/refs/heads/main/images/geographic_distribution_of_airports.png" width="900"></td>
#     <td><img src="https://raw.githubusercontent.com/william-shu-ucb/261-Final-Team-3_2/refs/heads/main/images/top_20_countries_by_airports.png" width="900"></td>
#   </tr>
# </table>
#
# Country-level analysis confirms that the dataset is dominated by U.S. airports (over 23,000 entries), followed by countries such as Brazil, Canada, and Australia. See Top 20 Countries by Airports histogram above. This geographic distribution aligns well with the airline dataset used in this project, which primarily focuses on U.S. domestic flight operations.
#
# The two datasets are linked using the airport identifier:
# df_stations.neighbor_call == df_airport_codes.ident
#
# <img src="https://raw.githubusercontent.com/william-shu-ucb/261-Final-Team-3_2/refs/heads/main/images/distribution_of_weather_station_distance_to_airports.png" width="600">

# %% [markdown]
# ### Weather Dataset
# The **Weather dataset`df_weather_full`** spans 2015–2021 and is sourced from the NOAA (National Oceanic and Atmospheric Administration). We conducted EDA on the three-month slice, **`df_weather_3m`** (January-March 2015), ingested in Parquet format. We used a checkpointing strategy by saving key transformations, such as cleaning columns and NULL values, to avoid rerunning expensive Spark operations.
#
# There are no duplicate rows in the dataset. However, **105 of 124** columns are missing values for at least half of all rows. This pattern likely reflect gaps in NOAA's reporting, where many weather variables are not measured at every station or at every point in time. Hourly metrics have much better data completeness compared to daily or monthly measurements, with daily and monthly null percentages exceeding 99%. As a result, we retain only hourly features with less than **50% missing values** for modeling. Several hourly columns were stored as strings despite being numeric, requiring regex-based cleaning and type casting before use. After dropping nulls across the selected hourly columns, **8,459,585 records** remain. The retained hourly features are: `HourlyDryBulbTemperature`, `HourlyWindSpeed`, `HourlyWindDirection`, `HourlyDewPointTemperature`, `HourlyRelativeHumidity`, `HourlyVisibility`, `HourlyAltimeterSetting`, `HourlySkyConditions`, and `HourlyStationPressure`.
#
# <table>
#   <tr>
#     <td><img src="https://raw.githubusercontent.com/william-shu-ucb/261-Final-Team-3_2/refs/heads/main/images/dry_bulb_temp_summary_stats.png" width="900"></td>
#     <td><img src="https://raw.githubusercontent.com/william-shu-ucb/261-Final-Team-3_2/refs/heads/main/images/station_pressure_summary_stats.png" width="900"></td>
#   </tr>
# </table>
#
# Post-cleaning distributions are **roughly symmetric** across most metrics, though `HourlyWindSpeed` has outliers above 50 mph, `HourlyVisibility` has extremes above 80 miles, and `HourlyStationPressure` shows low outliers around 18–19 inHg. Average temperature by hour follows an expected winter pattern, dipping to 32°F at hour 6 and peaking at 44°F at hour 15.
#
# <br><img src="https://raw.githubusercontent.com/william-shu-ucb/261-Final-Team-3_2/refs/heads/main/images/avg_hourly_temperature.png" width="600">
#
# None of the variables show strong correlations — except for the two temperature variables (`HourlyDryBulbTemperature` and `HourlyDewPointTemperature` at **0.88**), indicating **low multicollinearity risk** among the selected features.
#
# <br><img src="https://raw.githubusercontent.com/william-shu-ucb/261-Final-Team-3_2/refs/heads/main/images/weather_metrics_heatmap.png" width="600">

# %% [markdown]
# ### Flights Dataset
#
# The flights dataset (`df_flights`) contains domestic U.S. flight records ingested in Parquet format. The EDA focuses on the three-month subset (January–March 2015) to understand flight volume, delay patterns, and carrier and airport distributions before scaling to the full dataset.
#
# The dataset covers **14 unique carriers** and approximately **300 origin airports**. Flight volume varies significantly across carriers, with a small number of carriers accounting for the majority of flights. The top 20 busiest origin and destination airports are dominated by major U.S. hubs, consistent with the US-heavy nature of the dataset.
#
# <br><img src="https://raw.githubusercontent.com/william-shu-ucb/261-Final-Team-3_2/refs/heads/main/images/top_airports.png" width="600">
#
# Departure delay patterns show a clear time-of-day effect — average departure delays increase throughout the day, starting low in the early morning and rising steadily into the evening. This aligns with the well-known "delay propagation" effect, where delays accumulate across flights as the day progresses. Delay rates also vary by day of week and month, with certain days and months showing noticeably higher delay rates.
#
# <br><img src="https://raw.githubusercontent.com/william-shu-ucb/261-Final-Team-3_2/refs/heads/main/images/delay_rate_by_hour.png" width="600">
#
# Carrier delay rates vary considerably across airlines, suggesting that `OP_UNIQUE_CARRIER` will be a meaningful feature for modeling. Similarly, delay rates differ across origin airports, indicating that `ORIGIN` may also carry predictive signal for flight delays.

# %% [markdown]
# ### OTPW Dataset
#
# The primary dataset used in this project is the OTPW dataset (`df_otpw`), which combines airline On-Time Performance data with weather observations recorded at nearby weather stations. The three-month subset (January–March 2015) contains **1,401,363 rows and 216 columns**, reduced to **1,357,914 rows** after removing cancelled flights (3.10% of the dataset), as cancelled flights have no departure delay to predict.
#
# There are no duplicate rows. Similar to the weather dataset, **~105 columns contain more than 50% missing values**, mostly daily and monthly weather aggregates and ShortDuration fields, which will be dropped.
#
# The two target variables are **`DEP_DELAY`** (continuous, departure delay in minutes) and **`DEP_DEL15`** (binary, 1 = delayed ≥ 15 minutes). The dataset shows a **class imbalance** of approximately 80% on-time vs. 20% delayed flights, which will require strategies such as class weights or F-beta metrics during modeling. The `DEP_DELAY` distribution is heavily right-skewed, with most flights clustering between -15 and +30 minutes and a long tail of extreme outliers.
#
# <br><img src="https://raw.githubusercontent.com/william-shu-ucb/261-Final-Team-3_2/refs/heads/main/images/delay_distribution.png" width="600">
#
# Several temporal and operational delay patterns were identified. Delay rates increase throughout the day, peaking around 8PM. February has the highest delay rate among Q1 months, likely driven by winter weather.
#
# <br><img src="images/delay_by_month.png" width="600">
#
# Delay rates also vary significantly across carriers. As shown below, **Frontier** has the highest delay rate among all 14 carriers in the dataset, suggesting that carrier identity may be a meaningful predictor of flight delays.
#
# <br><img src="https://raw.githubusercontent.com/william-shu-ucb/261-Final-Team-3_2/refs/heads/main/images/delay_by_carrier.png" width="600">
#
# **22 leakage columns** were identified that would not be available two hours before departure (e.g. `DEP_TIME`, `ARR_DELAY`, `TAXI_OUT`, `WHEELS_OFF`, delay reason codes) and must be excluded from modeling features. The usable features include `DISTANCE`, `CRS_DEP_TIME`, `CRS_ELAPSED_TIME`, eight hourly weather columns (`HourlyDryBulbTemperature`, `HourlyDewPointTemperature`, `HourlyWindSpeed`, `HourlyWindDirection`, `HourlyVisibility`, `HourlyPrecipitation`, `HourlyRelativeHumidity`, `HourlyStationPressure`), and categorical features such as `OP_UNIQUE_CARRIER`, `ORIGIN`, `DEST`, `DAY_OF_WEEK`, and `MONTH`.

# %% [markdown]
# [Back to Table of Contents](#table-of-contents)

# %% [markdown]
# # Data Dictionary and Feature Engineering
#
# This project uses several datasets from the **On-Time Performance and Weather (OTPW)** repository to analyze the factors contributing to airline flight delays. The primary datasets include airline operational records, weather observations, weather station mappings, and airport metadata. Together, these datasets enable the integration of **temporal, operational, environmental, and network-based features** that may influence flight delays.

# %% [markdown]
# ### Flights Dataset
#
# The flights dataset contains historical airline operational records, including scheduled and actual departure times, arrival times, airline carrier information, and delay measurements.
#
# Key variables include:
#
# - `DEP_DELAY` – Departure delay in minutes (target variable)
# - `OP_UNIQUE_CARRIER` – Airline carrier identifier
# - `ORIGIN`, `DEST` – Origin and destination airport codes
# - `CRS_DEP_TIME` – Scheduled departure time
# - `DISTANCE` – Flight distance
# - `DAY_OF_WEEK`, `MONTH` – Temporal indicators
#
# This dataset provides the **core operational information** needed to model flight delays.

# %% [markdown]
# ### Weather Dataset
#
# The weather dataset contains hourly meteorological observations collected from weather stations. These observations provide environmental context that may influence flight operations.
#
# Example variables include:
#
# - `HourlyPrecipitation`
# - `HourlyVisibility`
# - `HourlyWindSpeed`
# - `HourlyDryBulbTemperature`
#
# Weather conditions are known to be significant contributors to flight delays, particularly during severe weather events.

# %% [markdown]
# ### Stations Dataset
#
# The stations dataset maps **weather stations to nearby airports**, allowing weather observations to be associated with specific airport locations.
#
# Important variables include:
#
# - `neighbor_call` – Airport identifier
# - `station_id` – Weather station identifier
# - `distance_to_neighbor` – Distance between weather station and airport
#
# Exploratory analysis shows that most airports are associated with nearby weather stations, although some airports rely on stations located farther away. This mapping enables weather observations to be integrated with flight data.

# %% [markdown]
# ### Airport Codes Dataset
#
# The airport codes dataset provides metadata describing airports worldwide.
#
# Key variables include:
#
# - `ident` – Airport identifier
# - `type` – Airport type (large, medium, small airport, heliport)
# - `iso_country` – Country code
# - `coordinates` – Geographic coordinates of the airport
#
# Analysis shows that the dataset is heavily skewed toward **U.S. airports**, which aligns well with the airline dataset used in this project.

# %% [markdown]
# ## Feature Engineering
#
# To support different modeling approaches, we will construct several groups of features from the datasets.

# %% [markdown]
# ### Time-Series Features
#
# Flight delays often exhibit **temporal patterns and delay propagation effects**, where earlier delays influence later flights. To capture these patterns, we will create time-based features such as:
#
# - Departure hour of day
# - Day of week and seasonal indicators
# - Rolling averages of historical delays at an airport
# - Lagged delay indicators for previous flights
# - Airport congestion indicators (number of departures within a time window)
#
# These features help capture **temporal dependencies and operational patterns** in airline networks.

# %% [markdown]
# ### Tabular Features for MLP and Tree-Based Models
#
# Multilayer Perceptrons (MLP) and tree-based models operate on structured tabular data. Features derived for these models include:
#
# Operational features:
#
# - Airline carrier
# - Flight distance
# - Origin and destination airports
#
# Weather features:
#
# - Wind speed
# - Precipitation
# - Visibility
# - Temperature
#
# Airport characteristics:
#
# - Airport type
# - Geographic region
# - Distance between weather station and airport
#
# Temporal features:
#
# - Hour of departure
# - Day of week
# - Month
#
# These features allow models to learn complex relationships between **operational, environmental, and temporal variables** affecting delays.

# %% [markdown]
# ### Graph-Based Features
#
# Air transportation networks naturally form a **graph structure**, where airports represent nodes and flights represent edges. Delays can propagate across this network as aircraft move between airports.
#
# To capture these network effects, we will construct graph-based features such as:
#
# - Airport degree (number of incoming/outgoing flights)
# - Network centrality measures (e.g., PageRank or betweenness centrality)
# - Airport connectivity within the flight network
# - Delay propagation indicators from upstream flights
#
# Graph-based features help represent **structural relationships within the aviation network** that may contribute to delay propagation.

# %% [markdown]
# By integrating **temporal, operational, environmental, and network-based features**, this dataset provides a rich foundation for building predictive models of flight delays. These features will support multiple modeling approaches, including regression models, neural networks, and graph-informed machine learning methods.

# %% [markdown]
# #Data Ingestion + Check Point Strategy

# %% [markdown]
# #Plan and Analysis for Missing and Duplication Data

# %% [markdown]
# [Back to Table of Contents](#table-of-contents)

# %% [markdown]
# # Machine Algorithms and Metrics

# %% [markdown]
# ### 1. Machine Learning Algorithms
#
# #### Problem Formulation
#
# A key challenge in the flight delay prediction problem is that predictions must be generated **at least two hours before a flight’s scheduled departure**, meaning that the model can only use information available prior to that time. This constraint introduces temporal dependencies because flight delays often propagate through the aviation system due to weather conditions, airport congestion, aircraft rotations, and operational disruptions.
#
# In this project, we treat the primary modeling task as a **regression problem**, where the goal is to predict the continuous delay variable `DEP_DELAY` (measured in minutes). Predicting the exact delay duration allows the model to capture the continuous nature of delay behavior and provides more detailed insight into operational conditions affecting flights. Additionally, flight delay data are typically **right-skewed**, with many flights experiencing little or no delay and a smaller number of flights experiencing large disruptions. This distribution motivates the use of models capable of handling nonlinear relationships and extreme values.
#
# For operational planning and communication purposes, the predicted delay values will then be converted into **three delay categories**:
#
# - **0–15 minutes:** No delay
# - **15–45 minutes:** Moderate delay
# - **45+ minutes:** Major delay
#
# These bins provide meaningful delay ranges that are easier for airlines, airport operators, and passengers to interpret and use for planning. This approach allows us to maintain the fidelity of a continuous prediction while translating results into **actionable delay categories**.
#
# Temporal information will be incorporated through features such as **departure time, day-of-week patterns, airport congestion indicators, and historical delay propagation patterns**.

# %% [markdown]
# #### Baseline Models
#
# We will begin with simple models to establish performance benchmarks for the regression formulation of the problem.
#
# **Linear Regression**
#
# - Implementation: Spark ML or scikit-learn
# - Objective: Predict continuous delay minutes (`DEP_DELAY`)
# - Loss Function: Mean Squared Error (MSE)
#
# $$
# MSE = \frac{1}{n} \sum_{i=1}^{n} (y_i - \hat{y}_i)^2
# $$
#
# Linear regression provides a simple and interpretable benchmark that allows us to compare the effectiveness of more complex nonlinear models.

# %% [markdown]
# #### Supporting Classification Baseline
#
# To complement the regression analysis, we will also evaluate a classification baseline using the delay categories derived from `DEP_DELAY`.
#
# **Logistic Regression (Multinomial)**
#
# - Implementation: Spark ML or scikit-learn
# - Objective: Predict delay categories derived from the operational delay bins
# - Loss Function: Log Loss
#
# $$
# L = -\frac{1}{n} \sum_{i=1}^{n} \left[y_i \log(\hat{y}_i) + (1-y_i)\log(1-\hat{y}_i)\right]
# $$
#
# Logistic regression provides a simple and interpretable baseline for delay classification and allows us to evaluate whether more complex models significantly improve predictive performance.

# %% [markdown]
# #### Tree-Based Ensemble Models
#
# Tree-based ensemble models are expected to perform well because they can capture **nonlinear relationships between weather conditions, airport characteristics, and operational factors**.
#
# Airline delay data involve complex interactions between variables such as weather conditions, airport congestion, carrier operations, and time-of-day patterns. Tree-based models can automatically capture these nonlinear relationships and feature interactions without requiring extensive manual feature engineering, which often leads to stronger predictive performance on structured tabular datasets.
#
# The following models will be evaluated:
#
# - **Random Forest**
#   - Bagging ensemble of decision trees
#   - Helps reduce variance and prevent overfitting
#
# - **Gradient Boosted Trees**
#   - Sequential boosting approach that reduces residual errors
#   - Often provides strong predictive performance for tabular data
#
# - **LightGBM**
#   - Histogram-based gradient boosting framework
#   - Efficient training on large datasets and well-suited for distributed environments

# %% [markdown]
# #### Neural Network Models
#
# We will also experiment with a **Multilayer Perceptron (MLP)**, a feedforward neural network capable of capturing nonlinear relationships across high-dimensional feature spaces. Neural networks may provide additional predictive power when interactions between features become highly complex.

# %% [markdown]
# ### 2. Successful Evaluation Metrics
#
# Because flight delays represent a relatively **rare event**, class imbalance is an important consideration when evaluating model performance. Therefore, we will use multiple evaluation metrics to assess how well the models identify delayed flights while minimizing false predictions.

# %% [markdown]
# #### Classification Metrics
#
# Since the primary task is to predict whether a flight will experience a significant delay (≥15 minutes), we will focus on the following classification metrics:
#
# **Accuracy**
#
# $$
# Accuracy = \frac{TP + TN}{TP + TN + FP + FN}
# $$
#
# Accuracy measures the proportion of correct predictions among all predictions.
#
# **Precision**
#
# $$
# Precision = \frac{TP}{TP + FP}
# $$
#
# Precision measures the proportion of predicted delayed flights that are actually delayed. High precision reduces false alarms.
#
# **Recall**
#
# $$
# Recall = \frac{TP}{TP + FN}
# $$
#
# Recall measures the proportion of actual delayed flights that are correctly identified. This metric is particularly important because failing to identify delays could lead to operational disruptions.
#
# **F1 Score**
#
# $$
# F1 = 2 \times \frac{Precision \times Recall}{Precision + Recall}
# $$
#
# The F1 score balances precision and recall, providing a single measure of overall classification performance.
#
# **ROC-AUC**
#
# The Area Under the Receiver Operating Characteristic Curve (ROC-AUC) measures the model’s ability to distinguish between delayed and on-time flights across different classification thresholds.

# %% [markdown]
# #### Regression Metrics
#
# In addition to classification, we will experiment with regression models that predict the continuous delay value (`DEP_DELAY`). These predictions may later be converted into delay categories for operational interpretation.
#
# **Mean Squared Error (MSE)**
#
# $$
# MSE = \frac{1}{n} \sum_{i=1}^{n} (y_i - \hat{y}_i)^2
# $$
#
# MSE measures the average squared difference between predicted and actual delay values.
#
# **Mean Absolute Error (MAE)**
#
# $$
# MAE = \frac{1}{n} \sum_{i=1}^{n} |y_i - \hat{y}_i|
# $$
#
# MAE measures the average absolute prediction error and is less sensitive to extreme outliers than MSE.

# %% [markdown]
# ### 3. Modeling Plan
#
# Our modeling workflow combines both **regression and classification approaches** to capture the continuous nature of delay times while producing operationally meaningful delay categories for decision-making.
#
# The modeling process will follow these steps:
#
# 1. **Define the operational delay targets.**
#    We define a **binary delay indicator using the 15-minute threshold** (delayed vs. on-time) while also preserving the continuous target variable `DEP_DELAY` for regression modeling.
#
# 2. **Train baseline models.**
#    We begin with interpretable baseline models such as **Linear Regression** for delay minutes and **Logistic Regression** for delay classification to establish performance benchmarks.
#
# 3. **Train more advanced machine learning models.**
#    We then train ensemble-based models including **Random Forest, Gradient Boosted Trees, and LightGBM** to capture nonlinear relationships and complex interactions among features.
#
# 4. **Evaluate regression performance.**
#    For models predicting `DEP_DELAY`, we evaluate performance using metrics such as **Mean Squared Error (MSE)** and **Mean Absolute Error (MAE)**.
#
# 5. **Convert regression predictions into operational delay categories.**
#    Predicted delay minutes are mapped into operational delay categories to support downstream classification evaluation and operational interpretation.
#
# 6. **Evaluate classification performance.**
#    Models are evaluated using metrics including **precision, recall, F1 score, and ROC-AUC**, with particular emphasis on **recall and F1 score** due to class imbalance in delay events.
#
# 7. **Compare models and analyze feature importance.**
#    We select the best-performing model based on overall predictive performance and analyze **feature importance** to identify key drivers of flight delays.
#
# Overall, the goal is to develop a model that produces **reliable early predictions of flight delays while minimizing false alarms and missed delay events**, enabling more effective operational planning for airlines and airports.

# %% [markdown]
# [Back to Table of Contents](#table-of-contents)

# %% [markdown]
# # Machine Learning Pipeline
#
# Our pipeline transforms raw flight and weather data into delay predictions through the following steps:

# %% [markdown]
# 1. **Data Ingestion & Checkpointing.**
#    Raw data is ingested in Parquet format using **Apache Spark** for distributed processing. Key transformation results are checkpointed to disk after expensive operations (e.g., null analysis, type casting) to avoid recomputation.
#
# 2. **Data Cleaning & Preprocessing.**
#    Cancelled flights and columns with >50% missing values are removed. Regex-based cleaning and type casting are applied to string-encoded numeric columns. All **22 leakage columns** that would not be available two hours before departure are excluded.
#
# 3. **Feature Engineering.**
#    All transformations are iimplemented using **Spark MLlib** to support distributed execution. Features are constructed across four categories: **temporal** (departure hour, day of week, month), **weather** (hourly temperature, wind speed, visibility, precipitation, humidity, pressure), **operational** (carrier, origin/destination airport, scheduled elapsed time, distance), and **historical** (rolling average delay by carrier and airport).
#
# 4. **Train / Validation / Test Split.**
#    Data is split **chronologically** to prevent data leakage — training on earlier periods and validating/testing on later ones. Normalization statistics (mean, std) are computed on the training set only and applied to validation and test sets.
#
# 5. **Model Training.**
#    We train and compare baseline models (**Linear Regression**, **Logistic Regression**), ensemble methods (**Random Forest**, **Gradient Boosted Trees**, **LightGBM**), and a **Multilayer Perceptron (MLP)** neural network, leveraging **Spark MLlib** for distributed model training where applicable.
#
# 6. **Model Evaluation.**
#    Regression models are evaluated on predicted **DEP_DEL** using **MSE and MAE**. Predicted delay values are then binned into on-time (< 15 min) and delayed (≥ 15 min) categories and evaluated using **Precision, Recall, F1 score, and ROC-AUC**, with emphasis on recall due to class imbalance.
#
#
# 7. **Feature Importance Analysis.**
#    We analyze feature importance from the best-performing model to identify the key drivers of flight delays and refine the feature set for subsequent phases.
#
# Overall, the goal is to develop a pipeline that produces **reliable early predictions of whether a flight will be delayed by 15 or more minutes**, enabling more effective operational planning for airlines and airports.
#
# <br><img src="https://raw.githubusercontent.com/william-shu-ucb/261-Final-Team-3_2/refs/heads/main/images/pipeline_diagram.png" width="600">
#
# *Figure: Machine learning pipeline used for flight delay prediction, from data ingestion through model evaluation.*

# %% [markdown]
# [Back to Table of Contents](#table-of-contents)

# %% [markdown]
# #Open Problems + Next Steps
